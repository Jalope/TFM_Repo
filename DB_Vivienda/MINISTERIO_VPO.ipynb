# %%
import pandas as pd
from pymongo import MongoClient
from collections import defaultdict
from urllib.parse import quote_plus
import requests

# %%
# Configurar conexión
usuario = "jalope"
contrasena = "admin"
host = "127.0.0.1"
puerto = "27250"

uri = f"mongodb://{quote_plus(usuario)}:{quote_plus(contrasena)}@{host}:{puerto}/?directConnection=true"
client = MongoClient(uri)
db = client["tfm_db"]

# %%
df = pd.read_csv("../data/VPOs/vpo_spain.csv", delimiter = ";")

# %%
df.head()
# Out:
#    total        year
# 0  44514  01/01/1991
# 1  35695  01/01/1992
# 2  45795  01/01/1993
# 3  67639  01/01/1994
# 4  71141  01/01/1995

# %%
df['year'] = pd.to_datetime(df['year'], format='%d/%m/%Y')

# %%
df.dtypes
# Out:
# total             int64
# year     datetime64[ns]
# dtype: object

# %%
coll = db['MINISTERIO_VPO']
coll.drop()
coll.insert_many(df.to_dict('records'))
print("Registros en la colección: ", coll.count_documents({}))
print("Número de filas de df: ", len(df))
# Out:
# Registros en la colección:  34
# Número de filas de df:  34

# %%
url = f"https://ec.europa.eu/eurostat/api/dissemination/sdmx/3.0/data/dataflow/ESTAT/gov_10a_exp/1.0/*.*.*.*.*.*?c[freq]=A&c[unit]=PC_GDP&c[sector]=S13&c[cofog99]=GF06&c[na_item]=TE&c[geo]=EU27_2020,EA20,EA19&c[TIME_PERIOD]=2023,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990&compress=true&format=csvdata&formatVersion=2.0&lang=en&labels=name"

# %%
df_raw = requests.get(url, params=None)
df_raw.raise_for_status()
df_raw = pd.read_csv(
    url,
    sep=',',
    compression='gzip',
    dtype=str,        # o tu mapeo de dtypes
    na_values=[':']   # si quieres interpretar ':' como NaN
)

# %%
df_raw.head()
# Out:
#   STRUCTURE            STRUCTURE_ID  \
# 0  dataflow  ESTAT:GOV_10A_EXP(1.0)
# 1  dataflow  ESTAT:GOV_10A_EXP(1.0)
# 2  dataflow  ESTAT:GOV_10A_EXP(1.0)
# 3  dataflow  ESTAT:GOV_10A_EXP(1.0)
# 4  dataflow  ESTAT:GOV_10A_EXP(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  General government expenditure by function (CO...    A         Annual
# 1  General government expenditure by function (CO...    A         Annual
# 2  General government expenditure by function (CO...    A         Annual
# 3  General government expenditure by function (CO...    A         Annual
# 4  General government expenditure by function (CO...    A         Annual
#
#      unit                             Unit of measure sector  \
# 0  PC_GDP  Percentage of gross domestic product (GDP)    S13
# 1  PC_GDP  Percentage of gross domestic product (GDP)    S13
# 2  PC_GDP  Percentage of gross domestic product (GDP)    S13
# 3  PC_GDP  Percentage of gross domestic product (GDP)    S13
# 4  PC_GDP  Percentage of gross domestic product (GDP)    S13
#
#                Sector cofog99  ...   geo  \
# 0  General government    GF06  ...  EA19
# 1  General government    GF06  ...  EA19
# 2  General government    GF06  ...  EA19
# 3  General government    GF06  ...  EA19
# 4  General government    GF06  ...  EA19
#
#          Geopolitical entity (reporting) TIME_PERIOD Time OBS_VALUE  \
# 0  Euro area - 19 countries  (2015-2022)        1995  NaN       1.1
# 1  Euro area - 19 countries  (2015-2022)        1996  NaN       0.7
# 2  Euro area - 19 countries  (2015-2022)        1997  NaN       0.8
# 3  Euro area - 19 countries  (2015-2022)        1998  NaN       0.8
# 4  Euro area - 19 countries  (2015-2022)        1999  NaN       0.8
#
#   Observation value OBS_FLAG Observation status (Flag) V2 structure  \
# 0               NaN      NaN                                    NaN
# 1               NaN      NaN                                    NaN
# 2               NaN      NaN                                    NaN
# 3               NaN      NaN                                    NaN
# 4               NaN      NaN                                    NaN
#
#   CONF_STATUS Confidentiality status (flag)
# 0         NaN                           NaN
# 1         NaN                           NaN
# 2         NaN                           NaN
# 3         NaN                           NaN
# 4         NaN                           NaN
#
# [5 rows x 23 columns]

# %%
df_raw.dtypes
# Out:
# STRUCTURE                                                     object
# STRUCTURE_ID                                                  object
# STRUCTURE_NAME                                                object
# freq                                                          object
# Time frequency                                                object
# unit                                                          object
# Unit of measure                                               object
# sector                                                        object
# Sector                                                        object
# cofog99                                                       object
# Classification of the functions of government (COFOG 1999)    object
# na_item                                                       object
# National accounts indicator (ESA 2010)                        object
# geo                                                           object
# Geopolitical entity (reporting)                               object
# TIME_PERIOD                                                   object
# Time                                                          object
# OBS_VALUE                                                     object
# Observation value                                             object
# OBS_FLAG                                                      object
# Observation status (Flag) V2 structure                        object
# CONF_STATUS                                                   object
# Confidentiality status (flag)                                 object
# dtype: object

# %%
# Seleccionar solo las columnas necesarias
df_clean = df_raw[['geo', 'TIME_PERIOD', 'OBS_VALUE']].copy()

# Renombrar columnas
df_clean.rename(columns={
    'TIME_PERIOD': 'year',
    'OBS_VALUE': 'pct_gdp'
}, inplace=True)

# Convertir tipos
df_clean['year'] = df_clean['year'].astype(int)
df_clean['pct_gdp'] = pd.to_numeric(df_clean['pct_gdp'], errors='coerce')
df_clean['geo'] = df_clean['geo'].astype(str)

# %%
df_clean.dtypes
# Out:
# geo         object
# year         int64
# pct_gdp    float64
# dtype: object

# %%
df_clean
# Out:
#           geo  year  pct_gdp
# 0        EA19  1995      1.1
# 1        EA19  1996      0.7
# 2        EA19  1997      0.8
# 3        EA19  1998      0.8
# 4        EA19  1999      0.8
# ..        ...   ...      ...
# 82  EU27_2020  2019      0.6
# 83  EU27_2020  2020      0.6
# 84  EU27_2020  2021      0.8
# 85  EU27_2020  2022      1.0
# 86  EU27_2020  2023      1.2
#
# [87 rows x 3 columns]

# %%
coll = db['EUROSTAT_GOV10aEXP_VIVIENDA']
coll.drop()
coll.insert_many(df_clean.to_dict('records'))
print("Registros en la colección: ", coll.count_documents({}))
print("Número de filas de df_clean: ", len(df_clean))
# Out:
# Registros en la colección:  87
# Número de filas de df_clean:  87

# %%
url = f"https://ec.europa.eu/eurostat/api/dissemination/sdmx/3.0/data/dataflow/ESTAT/gov_10a_exp/1.0/*.*.*.*.*.*?c[freq]=A&c[unit]=PC_GDP&c[sector]=S13&c[cofog99]=GF06&c[na_item]=TE&c[geo]=ES&c[TIME_PERIOD]=2023,2022,2021,2020,2019,2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990&compress=true&format=csvdata&formatVersion=2.0&lang=en&labels=name"

# %%
df_raw = requests.get(url, params=None)
df_raw.raise_for_status()
df_raw = pd.read_csv(
    url,
    sep=',',
    compression='gzip',
    dtype=str,        # o tu mapeo de dtypes
    na_values=[':']   # si quieres interpretar ':' como NaN
)

# %%
# Seleccionar solo las columnas necesarias
df = df_raw[['geo', 'TIME_PERIOD', 'OBS_VALUE']].copy()

# Renombrar columnas
df.rename(columns={
    'TIME_PERIOD': 'year',
    'OBS_VALUE': 'pct_gdp'
}, inplace=True)

# Convertir tipos
df['year'] = df['year'].astype(int)
df['pct_gdp'] = pd.to_numeric(df['pct_gdp'], errors='coerce')
df['geo'] = df['geo'].astype(str)

# %%
df
# Out:
#    geo  year  pct_gdp
# 0   ES  1995      1.0
# 1   ES  1996      1.0
# 2   ES  1997      1.0
# 3   ES  1998      1.1
# 4   ES  1999      1.1
# 5   ES  2000      1.2
# 6   ES  2001      1.0
# 7   ES  2002      1.0
# 8   ES  2003      1.1
# 9   ES  2004      0.8
# 10  ES  2005      0.9
# 11  ES  2006      0.8
# 12  ES  2007      0.9
# 13  ES  2008      1.1
# 14  ES  2009      1.3
# 15  ES  2010      0.7
# 16  ES  2011      0.6
# 17  ES  2012      0.6
# 18  ES  2013      0.5
# 19  ES  2014      0.5
# 20  ES  2015      0.5
# 21  ES  2016      0.4
# 22  ES  2017      0.4
# 23  ES  2018      0.4
# 24  ES  2019      0.4
# 25  ES  2020      0.5
# 26  ES  2021      0.5
# 27  ES  2022      0.5
# 28  ES  2023      0.5

# %%
# Asegúrate de que ambas tablas tengan los mismos tipos
df_clean['year']  = df_clean['year'].astype(int)
df_clean['geo']   = df_clean['geo'].astype(str)
df_clean['pct_gdp'] = pd.to_numeric(df_clean['pct_gdp'], errors='coerce')

df['year']  = df['year'].astype(int)
df['geo']   = df['geo'].astype(str)
df['pct_gdp'] = pd.to_numeric(df['pct_gdp'], errors='coerce')

# %%
df_combined = pd.concat([df_clean, df], ignore_index=True)

# %%
df_combined
# Out:
#       geo  year  pct_gdp
# 0    EA19  1995      1.1
# 1    EA19  1996      0.7
# 2    EA19  1997      0.8
# 3    EA19  1998      0.8
# 4    EA19  1999      0.8
# ..    ...   ...      ...
# 111    ES  2019      0.4
# 112    ES  2020      0.5
# 113    ES  2021      0.5
# 114    ES  2022      0.5
# 115    ES  2023      0.5
#
# [116 rows x 3 columns]

# %%
coll = db['EUROSTAT_GOV10aEXP_VIVIENDA']
coll.drop()
coll.insert_many(df_combined.to_dict('records'))
print("Registros en la colección: ", coll.count_documents({}))
print("Número de filas de df_clean: ", len(df_combined))
# Out:
# Registros en la colección:  116
# Número de filas de df_clean:  116
